# %%
# !pip install mysql.connector
# Out:
# ...
#   Created wheel for mysql.connector: filename=mysql_connector-2.2.9-cp37-cp37m-win_amd64.whl size=247951 sha256=3280da95979aebd1dab782427c9fcc069659eb98330d28def20aca0941463cdd
#   Stored in directory: C:\Users\aditm\AppData\Local\pip\Cache\wheels\8c\83\a1\f8b6d4bb1bd6208bbde1608bbfa7557504bed9eaf2ecf8c175
# Successfully built mysql.connector
# ...

# %%
import mysql.connector

mydb = mysql.connector.connect(
  host="http://disneydata.c6rvkyidwkym.us-east-2.rds.amazonaws.com/",
  user="admin",
  password="Disney2020",
  port = 3306
)

mycursor = mydb.cursor()

mycursor.execute("SHOW DATABASES")

for x in mycursor:
  print(x)
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\mysql\connector\network.py in open_connection(self)
#     484                                            0, socket.SOCK_STREAM,
# --> 485                                            socket.SOL_TCP)
#     486             # If multiple results we favor IPv4, unless IPv6 was forced.
#
# ~\AppData\Local\Continuum\anaconda3\lib\socket.py in getaddrinfo(host, port, family, type, proto, flags)
#     747     addrlist = []
# --> 748     for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     749         af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno 11001] getaddrinfo failed
#
# During handling of the above exception, another exception occurred:
#
# InterfaceError                            Traceback (most recent call last)
# ...

# %%
import numpy as np
import matplotlib as plt
import pandas as pd

# %%
Data = pd.read_csv("Data/Disney_Stock_Data.csv")

# %%
Disney_DF = pd.DataFrame(Data)

# %%
Disney_DF
# Out:
#            date      open      high       low     close    volume Unnamed: 6  \
# 0      1/4/2010   28.4371   28.8780   28.1021   28.2784  13700400        NaN
# 1      1/5/2010   28.2784   28.3578   27.9522   28.2079  10307700        NaN
# 2      1/6/2010   28.1285   28.2167   27.9345   28.0580  10709500        NaN
# 3      1/7/2010   28.0139   28.0932   27.8111   28.0668   8202100        NaN
# 4      1/8/2010   27.9169   28.1638   27.8023   28.1109   7657500        NaN
# ...         ...       ...       ...       ...       ...       ...        ...
# 2681  8/26/2020  130.0000  132.6000  129.5200  132.1800   8437001        NaN
# 2682  8/27/2020  133.0000  136.3600  132.8200  133.7300  13653303        NaN
# 2683  8/28/2020  134.5000  136.8000  133.5801  135.5400  11012240        NaN
# 2684  8/31/2020  135.2500  135.5400  131.2500  131.8700  11607827        NaN
# 2685   9/1/2020  131.9200  133.6100  130.8900  133.5500   6884202        NaN
#
# ...

# %%
Disney_DF.to_json(r'Data/DisneyData2.json',orient='records')

# %%
Disney_DF.to_sql('disney_stock_data', con=engine)

# %%
engine.execute("SELECT * FROM disney_stock_data").fetchall()
# Out:
# [(0, '1/4/2010', 28.4371, 28.878, 28.1021, 28.2784, 13700400),
#  (1, '1/5/2010', 28.2784, 28.3578, 27.9522, 28.2079, 10307700),
#  (2, '1/6/2010', 28.1285, 28.2167, 27.9345, 28.058000000000003, 10709500),
#  (3, '1/7/2010', 28.0139, 28.0932, 27.8111, 28.0668, 8202100),
#  (4, '1/8/2010', 27.9169, 28.1638, 27.8023, 28.1109, 7657500),
#  (5, '1/11/2010', 27.8023, 27.9874, 27.4143, 27.6524, 11250500),
#  (6, '1/12/2010', 27.3525, 27.4407, 27.0527, 27.1762, 14618300),
#  (7, '1/13/2010', 27.2379, 27.6612, 27.2203, 27.5906, 9620600),
#  (8, '1/14/2010', 27.4495, 27.4936, 27.2996, 27.3525, 9235600),
#  (9, '1/15/2010', 27.3437, 27.4672, 26.8147, 26.9822, 13936400),
#  (10, '1/19/2010', 26.9734, 27.5025, 26.894000000000002, 27.3437, 9662100),
#  (11, '1/20/2010', 27.3349, 27.5465, 27.088, 27.5025, 13302800),
#  (12, '1/21/2010', 27.4584, 27.7053, 26.9558, 26.991, 15403600),
#  (13, '1/22/2010', 26.894000000000002, 27.0792, 26.4091, 26.4355, 14459400),
# ...

# %%
Data = pd.read_csv("Data/Disney_Stock_Data_Month.csv")
Data.head()
# Out:
#                          date     open     high      low    close    volume
# 0     Monday, January 4, 2010  28.4371  28.8780  28.1021  28.2784  13700400
# 1    Tuesday, January 5, 2010  28.2784  28.3578  27.9522  28.2079  10307700
# 2  Wednesday, January 6, 2010  28.1285  28.2167  27.9345  28.0580  10709500
# 3   Thursday, January 7, 2010  28.0139  28.0932  27.8111  28.0668   8202100
# 4     Friday, January 8, 2010  27.9169  28.1638  27.8023  28.1109   7657500

# %%
Disney_DF = pd.DataFrame(Data)
Disney_DF
# Out:
#                             date      open      high       low     close  \
# 0        Monday, January 4, 2010   28.4371   28.8780   28.1021   28.2784
# 1       Tuesday, January 5, 2010   28.2784   28.3578   27.9522   28.2079
# 2     Wednesday, January 6, 2010   28.1285   28.2167   27.9345   28.0580
# 3      Thursday, January 7, 2010   28.0139   28.0932   27.8111   28.0668
# 4        Friday, January 8, 2010   27.9169   28.1638   27.8023   28.1109
# ...                          ...       ...       ...       ...       ...
# 2667      Friday, August 7, 2020  130.2200  131.9400  128.6600  129.9300
# 2668     Monday, August 10, 2020  129.7500  131.3200  128.4900  128.7900
# 2669    Tuesday, August 11, 2020  130.5300  132.7600  130.0000  130.4900
# 2670  Wednesday, August 12, 2020  130.6700  133.0000  130.4900  131.7900
# 2671   Thursday, August 13, 2020  130.6400  132.3500  130.4500  130.9600
#
#         volume
# 0     13700400
# 1     10307700
# 2     10709500
# 3      8202100
# ...

# %%
Disney_DF.to_json(r'Data/DisneyDataMonth.json',orient='records')

# %%
Data = pd.read_csv("Data/Disney_Stock_Year.csv")
Disney_DF = pd.DataFrame(Data)
Disney_DF.to_json(r'Data/DisneyData_Year.json',orient='records')

# %%
import sqlite3

# %%
conn = sqlite3.connect("Disney_DB.db")
c = conn.cursor()
c.execute('CREATE TABLE Disney (Date date, open number, high number, low number, close number, volume number)')

# %%
conn.commit()

# %%
Disney_DF.to_sql('disney_stock_data', conn, if_exists='replace', index = False)

# %%
c.execute('''  
SELECT * FROM Disney
          ''')

for row in c.fetchall():
    print (row)

# %%
# Create Engine and Pass in MySQL Connection

# Cloud MySQL Database Connection on AWS
engine = create_engine(f"mysql://{username}:{password}@{endpoint}:/{database}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-8cb1b3bdaca1> in <module>
#       2
#       3 # Cloud MySQL Database Connection on AWS
# ----> 4 engine = create_engine(f"mysql://{username}:{password}@{endpoint}:/{database}")
#
# NameError: name 'endpoint' is not defined

# %%
# Create a local database engine connection
local_conn = local_engine.connect()

# Create a remote database engine connection
conn = engine.connect()
